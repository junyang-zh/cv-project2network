# %% [markdown]
# # Age Estimation

# %%
import numpy as np
import os
from math import * 
from helperP import *

# %% [markdown]
# # Loading Data

# %%
base_dir = 'DATASET/'

age_train, features_train = prepare_data('train', base_dir)
age_val, features_val = prepare_data('val', base_dir)
_, features_test = prepare_data('test', base_dir)
show_data(base_dir)

# %% [markdown]
# ## Linear class
# 	LINEAR
# 	Implementation of the linear layer (also called fully connected layer)
# 	which performs linear transoformation on input data y = xW + b.
# 	This layer has two learnable parameters, weight of shape (input_channel, output_channel)
# 	and bias of shape (output_channel), which are specified and initalized in init_param()
# 	function. In this assignment, you need to implement both forward and backward computation
# 	Arguments:
# 		input_channel  -- integer, number of input channels
# 		output_channel -- integer, number of output channels

# %%
class Linear(object):

	def __init__(self, input_channel, output_channel):
		self.input_channel = input_channel
		self.output_channel = output_channel
		self.init_param()

	def init_param(self):
		##################################################
		# TODO: YOUR CODE HERE: init weights
		##################################################
		self.weight = None
		self.bias = None

	'''
		Forward computation of linear layer, you may want to save some intermediate
		variable to class membership (self.) for reusing in backward computation.
		Arguments:
			input -- numpy array of shape (N, input_channel)

		Output:
			output -- numpy array of shape (N, output_channel)
	'''
	def forward(self, input):
		self.input = input
		##################################################
		# TODO: YOUR CODE HERE: forward
		##################################################
		output = None
		return output

	'''
		Backward computation of linear layer, you need to compute the gradient
		w.r.t input, weight and bias respectively. You need to reuse the variable in forward
		computation to compute backward gradient.

		Arguments:
			grad_output -- numpy array of shape (N, output_channel)

		Output:
			grad_input -- numpy array of shape (N, input_channel), gradient w.r.t input
			grad_weight -- numpy array of shape (input_channel, output_channel), gradient w.r.t weight
			grad_bias --  numpy array of shape (output_channel), gradient w.r.t bias
	'''
	def backward(self, grad_input):
		##################################################
		# TODO: YOUR CODE HERE: backward
		##################################################
		grad_bias = None
		grad_weight = None
		grad_output = None
		return grad_output, grad_weight, grad_bias

# %% [markdown]
# ## CROSS_ENTROPY_LOSS_WITH_SOFTMAX
# 	Implementation of the combination of softmax function and cross entropy loss.
# 	In classification task, we usually firstly apply softmax to map class-wise prediciton
# 	into the probabiltiy distribution then we use cross entropy loss to maximise the likelihood
# 	of ground truth class's prediction. Since softmax includes exponential term and cross entropy includes
# 	log term, we can simplify the formula by combining these two functions togther so that log and exp term could cancell out
# 	mathmatically and we can avoid precision lost with float point numerical computation.
# 	If we ignore the index on batch sizel and assume there is only one grouth truth per sample,
# 	the formula for softmax and cross entropy loss are:
# 		Softmax: prob[i] = exp(x[i]) / \sum_{j}exp(x[j])
# 		Cross_entropy_loss:  - 1 * log(prob[gt_class])
# 	Combining these two function togther, we got
# 		cross_entropy_with_softmax: -x[gt_class] + log(\sum_{j}exp(x[j]))
# 	In this assignment, you will implement both forward and backward computation.
# 	Arguments:
# 		None

# %%
class CrossEntropyLossWithSoftmax(object):
	def __init__(self):
		pass
	'''
		Forward computation of cross entropy with softmax, you may want to save some intermediate variables to class membership (self.)
		Arguments:
			input    -- numpy array of shape (N, C), the prediction for each class, where C is number of class
			gt_label -- numpy array of shape (N), it's a integer array and the value range from 0 to C-1 which
						specify the ground truth class for each input
		Output:
			output   -- numpy array of shape (N), containing the cross entropy loss on each input
	'''
	def forward(self, input, gt_label):
		##################################################
		# TODO: YOUR CODE HERE: forward
		##################################################
		output = None
		return output

	'''
		Backward computation of cross entropy with softmax. It's recommended to resue the variable
		in forward computation to simplify the formula.
		Arguments:
			grad_output -- numpy array of shape (N)

		Output:
			grad_input  -- numpy array of shape (N, C), the gradient w.r.t input of forward function
	'''
	def backward(self, grad_output):
		##################################################
		# TODO: YOUR CODE HERE: backward
		##################################################
		grad_input = None
		return grad_input

# %% [markdown]
# # Implement Stochastic Gradient descent
# Stochastic Gradient Descent (SGD) is a simple yet very efficient approach to discriminative learning of linear classifiers under convex loss functions such as (linear) Support Vector Machines and Logistic Regression. Even though SGD has been around in the machine learning community for a long time, it has received a considerable amount of attention just recently in the context of large-scale learning.
# ```
# Arguments:
#     age          -- numpy array, label, (n, )
#     feature      -- numpy array, features, (n, 2048)
# Return:
#     weights      -- numpy array, (2048, )
#     bias         -- numpy array, (1, )
# ```

# %%
def stochastic_gradient_descent(age, feature, age_val, feature_val):
    # check the inputs
    assert len(age) == len(feature)

    # Set the random seed
    np.random.seed(0)

    # Define the layers
    fc = Linear(2048, 101)
    cretirion = CrossEntropyLossWithSoftmax()

    # Initialize parameters of the layers
    fc.init_param()

    # Number of mini-batches
    t = len(age) // batch_size

    # Optimal weights and loss for val
    weights_opt = []
    bias_opt = []
    loss_opt = 1e6

    for e in range(epoch_sgd):
        # Shuffle training data
        n = np.random.permutation(len(feature))

        for m in range(t):
            # Providing mini batch with fixed batch size of 16
            batch_feature = feature[n[m * batch_size: (m + 1) * batch_size]]
            batch_age = age[n[m * batch_size: (m + 1) * batch_size]].reshape(-1, 1).astype(np.int16).squeeze()

            # forward pass
            z = fc.forward(batch_feature)
            ce = cretirion.forward(z, batch_age)
            loss = ce.sum()

            # calculate gradient here
            dz = cretirion.backward(np.ones_like(ce))
            dinput, dweight, dbias = fc.backward(dz)

            # update the gradient here
            fc.weight -= dweight * lr
            fc.bias -= dbias * lr

        ##################################################
        # TODO: YOUR CODE HERE
        ##################################################
        # calcualte the loss on validation set
        pred_val = None
        loss_val = None


        if (loss_opt > loss_val):
            print('updated:')
            loss_opt = loss_val
            weights_opt = fc.weight
            bias_opt = fc.bias

        print('=> epoch:', e + 1, ' Validation Loss:', round(loss_val, 4))
    return weights_opt, bias_opt

# %% [markdown]
# # Train and validate

# %%
w, b = stochastic_gradient_descent(age_train, features_train, age_val, features_val)
loss, pred = evaluate(w, b, age_val, features_val)
print("Your validate loss is:", round(loss, 3))
# Out:
# updated:
# => epoch: 1  Validation Loss: 6.1028
# updated:
# => epoch: 2  Validation Loss: 5.3569
# updated:
# => epoch: 3  Validation Loss: 5.1183
# updated:
# => epoch: 4  Validation Loss: 5.0045
# updated:
# => epoch: 5  Validation Loss: 4.9479
# updated:
# => epoch: 6  Validation Loss: 4.9138
# updated:
# => epoch: 7  Validation Loss: 4.9038
# updated:
# => epoch: 8  Validation Loss: 4.8865
# updated:
# => epoch: 9  Validation Loss: 4.8762
# => epoch: 10  Validation Loss: 4.8777
# => epoch: 11  Validation Loss: 4.8908
# updated:
# => epoch: 12  Validation Loss: 4.8693
# updated:
# => epoch: 13  Validation Loss: 4.8667
# updated:
# => epoch: 14  Validation Loss: 4.8568
# updated:
# => epoch: 15  Validation Loss: 4.8533
# updated:
# => epoch: 16  Validation Loss: 4.8477
# => epoch: 17  Validation Loss: 4.853
# => epoch: 18  Validation Loss: 4.8492
# => epoch: 19  Validation Loss: 4.8494
# => epoch: 20  Validation Loss: 4.8485
# updated:
# => epoch: 21  Validation Loss: 4.829
# => epoch: 22  Validation Loss: 4.8362
# => epoch: 23  Validation Loss: 4.8434
# => epoch: 24  Validation Loss: 4.85
# => epoch: 25  Validation Loss: 4.8345
# => epoch: 26  Validation Loss: 4.8364
# => epoch: 27  Validation Loss: 4.8474
# => epoch: 28  Validation Loss: 4.8438
# => epoch: 29  Validation Loss: 4.833
# => epoch: 30  Validation Loss: 4.8383
# => epoch: 31  Validation Loss: 4.8293
# => epoch: 32  Validation Loss: 4.8451
# updated:
# => epoch: 33  Validation Loss: 4.8287
# => epoch: 34  Validation Loss: 4.8557
# => epoch: 35  Validation Loss: 4.8308
# => epoch: 36  Validation Loss: 4.8424
# => epoch: 37  Validation Loss: 4.8436
# => epoch: 38  Validation Loss: 4.8338
# => epoch: 39  Validation Loss: 4.8377
# => epoch: 40  Validation Loss: 4.8326
# => epoch: 41  Validation Loss: 4.8346
# => epoch: 42  Validation Loss: 4.8406
# => epoch: 43  Validation Loss: 4.8411
# => epoch: 44  Validation Loss: 4.83
# updated:
# => epoch: 45  Validation Loss: 4.828
# => epoch: 46  Validation Loss: 4.8297
# updated:
# => epoch: 47  Validation Loss: 4.821
# => epoch: 48  Validation Loss: 4.8385
# => epoch: 49  Validation Loss: 4.841
# => epoch: 50  Validation Loss: 4.8373
# => epoch: 51  Validation Loss: 4.8253
# => epoch: 52  Validation Loss: 4.8291
# => epoch: 53  Validation Loss: 4.8378
# updated:
# => epoch: 54  Validation Loss: 4.8148
# => epoch: 55  Validation Loss: 4.8264
# => epoch: 56  Validation Loss: 4.838
# => epoch: 57  Validation Loss: 4.829
# => epoch: 58  Validation Loss: 4.8187
# => epoch: 59  Validation Loss: 4.8257
# => epoch: 60  Validation Loss: 4.8449
# => epoch: 61  Validation Loss: 4.833
# => epoch: 62  Validation Loss: 4.8365
# => epoch: 63  Validation Loss: 4.8385
# => epoch: 64  Validation Loss: 4.8372
# => epoch: 65  Validation Loss: 4.8379
# => epoch: 66  Validation Loss: 4.8163
# => epoch: 67  Validation Loss: 4.829
# => epoch: 68  Validation Loss: 4.8268
# => epoch: 69  Validation Loss: 4.8191
# => epoch: 70  Validation Loss: 4.8511
# => epoch: 71  Validation Loss: 4.8232
# => epoch: 72  Validation Loss: 4.8301
# => epoch: 73  Validation Loss: 4.8341
# => epoch: 74  Validation Loss: 4.8241
# => epoch: 75  Validation Loss: 4.8414
# => epoch: 76  Validation Loss: 4.8318
# => epoch: 77  Validation Loss: 4.8243
# => epoch: 78  Validation Loss: 4.84
# => epoch: 79  Validation Loss: 4.833
# => epoch: 80  Validation Loss: 4.8301
# => epoch: 81  Validation Loss: 4.8313
# => epoch: 82  Validation Loss: 4.8355
# => epoch: 83  Validation Loss: 4.8311
# => epoch: 84  Validation Loss: 4.8394
# => epoch: 85  Validation Loss: 4.824
# => epoch: 86  Validation Loss: 4.825
# => epoch: 87  Validation Loss: 4.8249
# => epoch: 88  Validation Loss: 4.8239
# => epoch: 89  Validation Loss: 4.8306
# => epoch: 90  Validation Loss: 4.8272
# => epoch: 91  Validation Loss: 4.8232
# => epoch: 92  Validation Loss: 4.8209
# => epoch: 93  Validation Loss: 4.8174
# => epoch: 94  Validation Loss: 4.8323
# => epoch: 95  Validation Loss: 4.8349
# => epoch: 96  Validation Loss: 4.8196
# => epoch: 97  Validation Loss: 4.8332
# => epoch: 98  Validation Loss: 4.8379
# => epoch: 99  Validation Loss: 4.8221
# => epoch: 100  Validation Loss: 4.8205
# => epoch: 101  Validation Loss: 4.8243
# => epoch: 102  Validation Loss: 4.8279
# => epoch: 103  Validation Loss: 4.8318
# => epoch: 104  Validation Loss: 4.8314
# => epoch: 105  Validation Loss: 4.8254
# => epoch: 106  Validation Loss: 4.8255
# => epoch: 107  Validation Loss: 4.8348
# => epoch: 108  Validation Loss: 4.8258
# => epoch: 109  Validation Loss: 4.827
# => epoch: 110  Validation Loss: 4.8298
# => epoch: 111  Validation Loss: 4.8197
# => epoch: 112  Validation Loss: 4.8208
# => epoch: 113  Validation Loss: 4.8276
# => epoch: 114  Validation Loss: 4.8312
# => epoch: 115  Validation Loss: 4.8251
# => epoch: 116  Validation Loss: 4.8339
# => epoch: 117  Validation Loss: 4.8336
# => epoch: 118  Validation Loss: 4.8306
# => epoch: 119  Validation Loss: 4.8318
# => epoch: 120  Validation Loss: 4.8258
# => epoch: 121  Validation Loss: 4.8411
# => epoch: 122  Validation Loss: 4.8293
# => epoch: 123  Validation Loss: 4.8228
# => epoch: 124  Validation Loss: 4.8315
# => epoch: 125  Validation Loss: 4.8268
# => epoch: 126  Validation Loss: 4.838
# => epoch: 127  Validation Loss: 4.8227
# => epoch: 128  Validation Loss: 4.8274
# => epoch: 129  Validation Loss: 4.8275
# => epoch: 130  Validation Loss: 4.8406
# => epoch: 131  Validation Loss: 4.8175
# => epoch: 132  Validation Loss: 4.8273
# => epoch: 133  Validation Loss: 4.8333
# => epoch: 134  Validation Loss: 4.8346
# => epoch: 135  Validation Loss: 4.8364
# => epoch: 136  Validation Loss: 4.8212
# => epoch: 137  Validation Loss: 4.8214
# => epoch: 138  Validation Loss: 4.8322
# => epoch: 139  Validation Loss: 4.8348
# => epoch: 140  Validation Loss: 4.829
# => epoch: 141  Validation Loss: 4.8246
# => epoch: 142  Validation Loss: 4.8396
# => epoch: 143  Validation Loss: 4.837
# => epoch: 144  Validation Loss: 4.8388
# => epoch: 145  Validation Loss: 4.8359
# => epoch: 146  Validation Loss: 4.8447
# => epoch: 147  Validation Loss: 4.819
# => epoch: 148  Validation Loss: 4.8303
# => epoch: 149  Validation Loss: 4.8288
# updated:
# => epoch: 150  Validation Loss: 4.8108
# => epoch: 151  Validation Loss: 4.8304
# => epoch: 152  Validation Loss: 4.8357
# => epoch: 153  Validation Loss: 4.8274
# => epoch: 154  Validation Loss: 4.8266
# => epoch: 155  Validation Loss: 4.8356
# => epoch: 156  Validation Loss: 4.8346
# => epoch: 157  Validation Loss: 4.8343
# => epoch: 158  Validation Loss: 4.8308
# => epoch: 159  Validation Loss: 4.8219
# => epoch: 160  Validation Loss: 4.8505
# => epoch: 161  Validation Loss: 4.8352
# => epoch: 162  Validation Loss: 4.8478
# => epoch: 163  Validation Loss: 4.8315
# => epoch: 164  Validation Loss: 4.8342
# => epoch: 165  Validation Loss: 4.8367
# => epoch: 166  Validation Loss: 4.8357
# => epoch: 167  Validation Loss: 4.8329
# => epoch: 168  Validation Loss: 4.8305
# => epoch: 169  Validation Loss: 4.8202
# => epoch: 170  Validation Loss: 4.8346
# => epoch: 171  Validation Loss: 4.8341
# => epoch: 172  Validation Loss: 4.8307
# => epoch: 173  Validation Loss: 4.8329
# => epoch: 174  Validation Loss: 4.8408
# => epoch: 175  Validation Loss: 4.8204
# => epoch: 176  Validation Loss: 4.8256
# => epoch: 177  Validation Loss: 4.8429
# => epoch: 178  Validation Loss: 4.8426
# => epoch: 179  Validation Loss: 4.8306
# => epoch: 180  Validation Loss: 4.8293
# => epoch: 181  Validation Loss: 4.8332
# => epoch: 182  Validation Loss: 4.8298
# => epoch: 183  Validation Loss: 4.8309
# => epoch: 184  Validation Loss: 4.8266
# => epoch: 185  Validation Loss: 4.8352
# => epoch: 186  Validation Loss: 4.8308
# => epoch: 187  Validation Loss: 4.8394
# => epoch: 188  Validation Loss: 4.8294
# => epoch: 189  Validation Loss: 4.8261
# => epoch: 190  Validation Loss: 4.8434
# => epoch: 191  Validation Loss: 4.8343
# => epoch: 192  Validation Loss: 4.8201
# => epoch: 193  Validation Loss: 4.8231
# => epoch: 194  Validation Loss: 4.8248
# => epoch: 195  Validation Loss: 4.8252
# => epoch: 196  Validation Loss: 4.8395
# => epoch: 197  Validation Loss: 4.8265
# => epoch: 198  Validation Loss: 4.8316
# => epoch: 199  Validation Loss: 4.8383
# => epoch: 200  Validation Loss: 4.8244
# Your validate score is: 4.824355

# %% [markdown]
# # Test and Generate results file

# %%
prediction = test(w, b, features_test, filename='softmax.txt')
print("Test results has saved to softmax.txt")
print(prediction[:10])
# Out:
# Test results has saved to softmax.txt
# [25.52046239 61.61712898 50.41595047 20.94345005 31.02992081 35.028581
#  49.49936787 41.24668554 21.77947753 57.41721833]
